# %% [markdown]
# ## Questions

# %% [markdown]
# ### What is Chi-square distribution?

# %% [markdown]
# ### What is 20-m  shuttle  run  test?

# %% [markdown]
# ### What is F-Test
#
# F-Test can be used to test if the standard deviation of the 2 dataset is statistically different.

# %%
from IPython.lib.display import YouTubeVideo

YouTubeVideo('FlIiYdHHpwU')

# %% [markdown]
# ## How multple regression equation can be generated?
#
# See [3].
#
# See [4] p 342

# %% [markdown]
# What are other project idea?
#
# * Extracting training strategy infomation for a specific marathon
# * Extracting marathon course featues and info
# * Race time prediction using historical race open data like nyrr, athlinks
